# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 580

# %%
cities
# Out:
# ['alice springs',
#  'ust-nera',
#  'fortuna',
#  'rikitea',
#  'katsuura',
#  'nesbyen',
#  'atuona',
#  'ilhabela',
#  'mataura',
#  'camacha',
#  'namatanai',
#  'sitka',
#  'pangody',
#  'yulara',
#  'klaksvik',
#  'kaitangata',
#  'khatanga',
#  'severo-kurilsk',
#  'punta arenas',
#  'maceio',
#  'lasa',
#  'narsaq',
#  'skegness',
#  'albany',
#  'tasiilaq',
#  'katobu',
#  'norman wells',
#  'hilo',
#  'fengcheng',
#  'saint anthony',
#  'ushuaia',
#  'busselton',
#  'lazaro cardenas',
#  'ponta do sol',
#  'bathsheba',
#  'avera',
#  'luwuk',
#  'buariki',
#  'beaverlodge',
#  'barentsburg',
#  'naze',
#  'saint george',
#  'sioux lookout',
#  'komatsu',
#  'beni mazar',
#  'vestmannaeyjar',
#  'aswan',
#  'nuuk',
#  'dikson',
#  'bluff',
#  'souillac',
#  'warrnambool',
#  'qaanaaq',
#  'kapaa',
#  'thompson',
#  'taolanaro',
#  'jamestown',
#  'luderitz',
#  'tuatapere',
#  'hobart',
#  'cape town',
#  'barrow',
#  'san francisco',
#  'cherskiy',
#  'saldanha',
#  'thinadhoo',
#  'porto nacional',
#  'cabo san lucas',
#  'markala',
#  'salalah',
#  'illoqqortoormiut',
#  'henties bay',
#  'berlevag',
#  'adrar',
#  'melnikovo',
#  'port alfred',
#  'byron bay',
#  'upernavik',
#  'coquimbo',
#  'mar del plata',
#  'provideniya',
#  'tumannyy',
#  'bredasdorp',
#  'pochutla',
#  'novyy svit',
#  'port macquarie',
#  'sao filipe',
#  'namwala',
#  'vaini',
#  'new norfolk',
#  'palmer',
#  'taburi',
#  'avarua',
#  'kulu',
#  'batticaloa',
#  'tautira',
#  'vigrestad',
#  'cap malheureux',
#  'belushya guba',
#  'pemangkat',
#  'arraial do cabo',
#  'bangkalan',
#  'sentyabrskiy',
#  'santa maria',
#  'vostok',
#  'sibu',
#  'esperance',
#  'kashi',
#  'hermanus',
#  'chuy',
#  'pasighat',
#  'georgetown',
#  'saint-philippe',
#  'srednekolymsk',
#  'castro',
#  'tuktoyaktuk',
#  'hobyo',
#  'mahebourg',
#  'hasaki',
#  'presidente medici',
#  'torbay',
#  'brae',
#  'nikolskoye',
#  'taboc',
#  'dwarka',
#  'pevek',
#  'caluquembe',
#  'coihaique',
#  'waddan',
#  'marcona',
#  'richards bay',
#  'westpunt',
#  'constitucion',
#  'kuche',
#  'ancud',
#  'huron',
#  'auki',
#  'camopi',
#  'zeya',
#  'sinnamary',
#  'qaqortoq',
#  'gat',
#  'mundo novo',
#  'palabuhanratu',
#  'raudeberg',
#  'lagoa',
#  'borzya',
#  'bengkulu',
#  'saint-joseph',
#  'vardo',
#  'san quintin',
#  'wanning',
#  'lata',
#  'quepos',
#  'basco',
#  'hvide sande',
#  'iqaluit',
#  'varjota',
#  'butaritari',
#  'carnarvon',
#  'bilibino',
#  'jiujiang',
#  'bull savanna',
#  'pisco',
#  'slave lake',
#  'yuzhno-yeniseyskiy',
#  'mys shmidta',
#  'ekimchan',
#  'ribeira grande',
#  'puerto ayora',
#  'tsihombe',
#  'amarante do maranhao',
#  'husavik',
#  'sabang',
#  'zavetnoye',
#  'aripuana',
#  'lichinga',
#  'poum',
#  'mao',
#  'faya',
#  'zhigansk',
#  'warken',
#  'guerrero negro',
#  'burnie',
#  'lavrentiya',
#  'rancho veloz',
#  'ulladulla',
#  'boyuibe',
#  'tatarsk',
#  'saskylakh',
#  'nouadhibou',
#  'hithadhoo',
#  'gravelbourg',
#  'bodhan',
#  'markivka',
#  'havoysund',
#  'cayenne',
#  'mercedes',
#  'general roca',
#  'macau',
#  'koudougou',
#  'bukachacha',
#  'airai',
#  'te anau',
#  'samarai',
#  'kandry',
#  'namibe',
#  'bambous virieux',
#  'chokurdakh',
#  'yellowknife',
#  'banff',
#  'kuito',
#  'cidreira',
#  'aktau',
#  'nanortalik',
#  'linkou',
#  'grindavik',
#  'attawapiskat',
#  'saleaula',
#  'xining',
#  'nichinan',
#  'keti bandar',
#  'kodiak',
#  'larsnes',
#  'bulolo',
#  'garowe',
#  'machiques',
#  'karratha',
#  'springbok',
#  'port elizabeth',
#  'tecoanapa',
#  'yaan',
#  'simbahan',
#  'bud',
#  'fengzhen',
#  'montabaur',
#  'alofi',
#  'warqla',
#  'muros',
#  'faanui',
#  'turayf',
#  'sept-iles',
#  'filadelfia',
#  'mamlyutka',
#  'suba',
#  'bonthe',
#  'nizhneyansk',
#  'cassia',
#  'santa marta',
#  'homer',
#  'amderma',
#  'rio grande',
#  'linkoping',
#  'lompoc',
#  'pangnirtung',
#  'winslow',
#  'barra do garcas',
#  'tezu',
#  'tawzar',
#  'lodja',
#  'oistins',
#  'kandrian',
#  'lebu',
#  'christchurch',
#  'lorengau',
#  'longyearbyen',
#  'beloha',
#  'prince rupert',
#  'martapura',
#  'vila franca do campo',
#  'kavieng',
#  'ixtapa',
#  'kosh-agach',
#  'los andes',
#  'santa lucia',
#  'bay roberts',
#  'viedma',
#  'evensk',
#  'olafsvik',
#  'isangel',
#  'eminabad',
#  'ambon',
#  'batemans bay',
#  'flin flon',
#  'nabire',
#  'ambodifototra',
#  'sola',
#  'kijabe',
#  'kuminskiy',
#  'sabratah',
#  'berliste',
#  'rurrenabaque',
#  'mount gambier',
#  'clyde river',
#  'saint-augustin',
#  'nautla',
#  'roald',
#  'malanville',
#  'mujiayingzi',
#  'ambalavao',
#  'yeppoon',
#  'zilair',
#  'kamaishi',
#  'aklavik',
#  'frolovo',
#  'laguna',
#  'sao joao da barra',
#  'tual',
#  'bend',
#  'sharlyk',
#  'neryungri',
#  'mozarlandia',
#  'koungheul',
#  'ust-ilimsk',
#  'pangkalanbuun',
#  'puerto el triunfo',
#  'ilulissat',
#  'plettenberg bay',
#  'do gonbadan',
#  'sorong',
#  'vao',
#  'dzilam gonzalez',
#  'tiksi',
#  'brigham city',
#  'beringovskiy',
#  'bethel',
#  'fort nelson',
#  'alta floresta',
#  'raymondville',
#  'araouane',
#  'pemba',
#  'yangambi',
#  'meulaboh',
#  'kahului',
#  'katherine',
#  'belyy yar',
#  'lolua',
#  'belmonte',
#  'burica',
#  'deputatskiy',
#  'ogaminana',
#  'victoria',
#  'portland',
#  'itaituba',
#  'acapulco',
#  'hualmay',
#  'ponta delgada',
#  'luganville',
#  'hohhot',
#  'vysokaya gora',
#  'ovre ardal',
#  'pundaguitan',
#  'grand river south east',
#  'kawambwa',
#  'porbandar',
#  'vaitupu',
#  'soria',
#  'opuwo',
#  'clarence town',
#  'savonlinna',
#  'margate',
#  'wajir',
#  'puerto del rosario',
#  'del rio',
#  'cairns',
#  'zheleznodorozhnyy',
#  'uong bi',
#  'shelburne',
#  'manggar',
#  'krasnogorskoye',
#  'codrington',
#  'talnakh',
#  'penzance',
#  'one hundred mile house',
#  'helong',
#  'stornoway',
#  'iranshahr',
#  'santa isabel',
#  'channel-port aux basques',
#  'xuddur',
#  'twentynine palms',
#  'hare bay',
#  'ballina',
#  'port hardy',
#  'northam',
#  'uyuni',
#  'abapo',
#  'broken hill',
#  'osakarovka',
#  'touros',
#  'kutum',
#  'gazojak',
#  'nakskov',
#  'port hawkesbury',
#  'puerto escondido',
#  'ossora',
#  'sindhnur',
#  'nizhnyaya pavlovka',
#  'oberkirch',
#  'labuan',
#  'ourossogui',
#  'port hedland',
#  'polyarnyy',
#  'hangu',
#  'daitari',
#  'tabas',
#  'tahe',
#  'hami',
#  'kaduqli',
#  'yamada',
#  'qui nhon',
#  'phan thiet',
#  'mont-dore',
#  'evinayong',
#  'hofn',
#  'chernyshevskiy',
#  'taltal',
#  'louisbourg',
#  'roebourne',
#  'carlyle',
#  'cabedelo',
#  'porto novo',
#  'acari',
#  'ranong',
#  'san cristobal',
#  'tulum',
#  'coahuayana',
#  'sorvag',
#  'mehamn',
#  'los llanos de aridane',
#  'rosarito',
#  'east london',
#  'fevralsk',
#  'jalu',
#  'baykit',
#  'port blair',
#  'venado tuerto',
#  'eyl',
#  'san patricio',
#  'asau',
#  'comodoro rivadavia',
#  'coruripe',
#  'neuenhagen',
#  'salvador',
#  'novopskov',
#  'slobozia',
#  'biak',
#  'kedrovyy',
#  'oranjemund',
#  'barentu',
#  'palu',
#  'baiyin',
#  'angoche',
#  'nizwa',
#  'doha',
#  'baturaja',
#  'jambi',
#  'kidal',
#  'ayolas',
#  'erenhot',
#  'neyshabur',
#  'lapa',
#  'hudson bay',
#  'store heddinge',
#  'emba',
#  'piryion',
#  'linjiang',
#  'tabiauea',
#  'osijek',
#  'korla',
#  'stulovo',
#  'omsukchan',
#  'upata',
#  'innisfail',
#  'kruisfontein',
#  'aratoca',
#  'itoman',
#  'rocha',
#  'bolshoye nagatkino',
#  'grand gaube',
#  'joshimath',
#  'dillon',
#  'benjamin hill',
#  'santa vitoria do palmar',
#  'nara',
#  'tubruq',
#  'kyaikkami',
#  'road town',
#  'saint-pierre',
#  'karasburg',
#  'ketchikan',
#  'tabukiniberu',
#  'banjar',
#  'smithers',
#  'kyshtovka',
#  'lukovetskiy',
#  'chulman',
#  'chapais',
#  'ibra',
#  'balkhash',
#  'najran',
#  'dunedin',
#  'saposoa',
#  'reyes',
#  'zyryanka',
#  'dzaoudzi',
#  'sobolevo',
#  'kindu',
#  'rawannawi',
#  'minot',
#  'libreville',
#  'kytlym',
#  'lephepe',
#  'mutsu',
#  'broadstairs',
#  'mangrol',
#  'gorodovikovsk',
#  'clovis',
#  'lexington park',
#  'farafangana',
#  'mpongwe',
#  'johnson city',
#  'tiszaroff',
#  'kirkuk',
#  'fomboni',
#  'darnah',
#  'kamenskoye',
#  'kenai',
#  'sangmelima',
#  'nouakchott',
#  'nome',
#  'phan rang',
#  'astrea',
#  'estelle',
#  'sergeyevka',
#  'madang',
#  'bushehr',
#  'copiapo',
#  'kununurra',
#  'agadir',
#  'kerema',
#  'abu samrah',
#  'leningradskiy',
#  'sierra vista',
#  'esmeralda',
#  'sorland',
#  'tukrah',
#  'rincon',
#  'yar-sale',
#  'veraval',
#  'gizo',
#  'sarangani',
#  'derzhavinsk',
#  'ostrovnoy',
#  'curup',
#  'belur',
#  'doctor juan leon mallorquin',
#  'the valley',
#  'shimoda',
#  'churapcha',
#  'chesterton',
#  'acajutla',
#  'maralal',
#  'vung tau',
#  'lae',
#  'labutta',
#  'bandarbeyla',
#  'husainabad',
#  'edson',
#  'salinopolis',
#  'roma',
#  'imbituba',
#  'zavallya',
#  'sucua',
#  'jumla',
#  'tagusao',
#  'shipunovo',
#  'miles city',
#  'satitoa',
#  'asyut']

# %%
cities_df=pd.DataFrame({"City": cities})
cities_df.head()
# Out:
#             City
# 0  alice springs
# 1       ust-nera
# 2        fortuna
# 3        rikitea
# 4       katsuura

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
#cities[]
query_url= f"{url}appid={api_key}&q="
city_data = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
for index, row in cities_df.iterrows():
    
    response = requests.get(query_url+city+"&units=imperial").json()
    #city_data.append(response['city'])
    cloudiness.append(response['clouds']['all'])
    country.append(response['sys']['country'])
    date.append(response['dt'])
    humidity.append(response['main']['humidity'])
    lat.append(response['coord']['lat'])
    lng.append(response['coord']['lon'])
    max_temp.append(response['main']['temp_max'])
    wind_speed.append(response['wind']['speed'])
# pprint(response)
print(max_temp)
# Out:
# [25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25.41, 25 ...

# %%
for index, row in cities_df.iterrows():
    response = requests.get(query_url+city+"&units=imperial").json()
#         if 'error' not in response:
    try:
        city_data.append([response["clouds.all"]])
    except (KeyError):
        print("Missing url/result... skippng.")     
dataset = pd.DataFrame(city_data)
dataset.head()

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url= f"{url}appid={api_key}&q="
response= requests.get(query_url + 'kytlym' + "&units=imperial").json()
helena_data=response["clouds"]["all"]
helena_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-71ceffdc53e8> in <module>
#       2 query_url= f"{url}appid={api_key}&q="
#       3 response= requests.get(query_url + 'kytlym' + "&units=imperial").json()
# ----> 4 helena_data=response["clouds"]["all"]
#       5 helena_data
#
# KeyError: 'clouds'

# %%
for city in cities:
    
    response = requests.get(query_url+city+"&units=imperial").json()
    #city_data.append(response['city'])
    cloudiness.append(response['clouds']['all'])
    country.append(response['sys']['country'])
    date.append(response['dt'])
    humidity.append(response['main']['humidity'])
    lat.append(response['coord']['lat'])
    lng.append(response['coord']['lon'])
    max_temp.append(response['main']['temp_max'])
    wind_speed.append(response['wind']['speed'])
# pprint(response)
print(f"the cloudiness is: {cloudiness}")

# %%
response.value_counts()

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({"City": cities,
               "Cloudiness": cloudiness,
               "Country": country,
               "Date": date,
               "Humidity": humidity,
               "Lat": lat,
               "Lng": lng,
               "Max Temp": max_temp,
               "Wind Speed": wind_speed,
               })
weather_data

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
